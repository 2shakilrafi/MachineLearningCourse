# %%
import pandas as pd
import numpy as np

raw_data = pd.read_csv("raw_data_cleaned_july.csv")

# %%
raw_data
# Out:
#      Unnamed: 0        GEOID  MedianIncome  Pickup  TotalPopulation  \
# 0             0  17031010201         41125  1837.0             7039
# 1             1  17031010202         45236  1375.0             2852
# 2             2  17031010300         72917  1627.0             6650
# 3             3  17031010400         58438  1204.0             5153
# 4             4  17031010501         52747  1310.0             4147
# ..          ...          ...           ...     ...              ...
# 890         918  17031843500         28750   150.0            10317
# 891         919  17031843600         67609   915.0             2918
# 892         920  17031843700        194375  1843.0             2617
# 893         921  17031843800         41250    58.0             1482
# 894         922  17031843900         50104  1619.0             3521
#
#      Population_Density   Employment_Density  Percent_Zero_Car_Ownership  \
# 0             59.119022             1.490412                    0.019724
# ...

# %%
raw_data = raw_data.rename(columns={"Distancefromthepopulation-weightedcentroidto nearesttransit station": "Distance_from_transit"})

# %%
raw_data
# Out:
#      Unnamed: 0        GEOID  MedianIncome  Pickup  TotalPopulation  \
# 0             0  17031010201         41125  1837.0             7039
# 1             1  17031010202         45236  1375.0             2852
# 2             2  17031010300         72917  1627.0             6650
# 3             3  17031010400         58438  1204.0             5153
# 4             4  17031010501         52747  1310.0             4147
# ..          ...          ...           ...     ...              ...
# 890         918  17031843500         28750   150.0            10317
# 891         919  17031843600         67609   915.0             2918
# 892         920  17031843700        194375  1843.0             2617
# 893         921  17031843800         41250    58.0             1482
# 894         922  17031843900         50104  1619.0             3521
#
#      Population_Density   Employment_Density  Percent_Zero_Car_Ownership  \
# 0             59.119022             1.490412                    0.019724
# ...

# %%
raw_data.shape
# Out:
# (895, 10)

# %%
raw_data.describe()
# Out:
#        Unnamed: 0         GEOID   MedianIncome        Pickup  TotalPopulation  \
# count  895.000000  8.950000e+02     895.000000    834.000000       895.000000
# mean   454.216760  1.703146e+10   84168.846927   1449.500000      3685.832402
# std    266.201266  2.970138e+05   54197.373888   4036.743782      1835.669104
# min      0.000000  1.703101e+10   11457.000000      1.000000       416.000000
# 25%    223.500000  1.703119e+10   44920.000000     92.500000      2279.000000
# 50%    453.000000  1.703144e+10   67044.000000    317.500000      3489.000000
# 75%    682.500000  1.703181e+10  107213.000000   1058.750000      4865.500000
# max    922.000000  1.703184e+10  250000.000000  44804.000000     19889.000000
#
#        Population_Density   Employment_Density  Percent_Zero_Car_Ownership  \
# count          895.000000           895.000000                  895.000000
# mean            31.126855            11.433281                    0.207805
# ...

# %%
raw_data = raw_data.rename(columns={"Population_Denisty": "Population_Density", " TotalPopulation": "TotalPopulation"})
raw_data.shape
# Out:
# (895, 10)

# %%
raw_data=raw_data[raw_data["Population_Density"] > 0]
raw_data.shape
# Out:
# (895, 10)

# %%
raw_data = raw_data[raw_data["Distance_from_transit"] >= 0]
raw_data.shape
# Out:
# (895, 10)

# %%
raw_data = raw_data[raw_data["MedianIncome"]>0]

# %%
raw_data.shape
# Out:
# (895, 10)

# %%
raw_data.describe()
# Out:
#        Unnamed: 0         GEOID   MedianIncome        Pickup  TotalPopulation  \
# count  895.000000  8.950000e+02     895.000000    834.000000       895.000000
# mean   454.216760  1.703146e+10   84168.846927   1449.500000      3685.832402
# std    266.201266  2.970138e+05   54197.373888   4036.743782      1835.669104
# min      0.000000  1.703101e+10   11457.000000      1.000000       416.000000
# 25%    223.500000  1.703119e+10   44920.000000     92.500000      2279.000000
# 50%    453.000000  1.703144e+10   67044.000000    317.500000      3489.000000
# 75%    682.500000  1.703181e+10  107213.000000   1058.750000      4865.500000
# max    922.000000  1.703184e+10  250000.000000  44804.000000     19889.000000
#
#        Population_Density   Employment_Density  Percent_Zero_Car_Ownership  \
# count          895.000000           895.000000                  895.000000
# mean            31.126855            11.433281                    0.207805
# ...

# %%
raw_data = raw_data.rename(columns={" LandUse_Diversity":"LandUse_Diversity"})

# %%
raw_data = raw_data[raw_data["LandUse_Diversity"]>0]

# %%
raw_data.shape
# Out:
# (895, 10)

# %%
raw_data.describe()
# Out:
#        Unnamed: 0         GEOID   MedianIncome        Pickup  TotalPopulation  \
# count  895.000000  8.950000e+02     895.000000    834.000000       895.000000
# mean   454.216760  1.703146e+10   84168.846927   1449.500000      3685.832402
# std    266.201266  2.970138e+05   54197.373888   4036.743782      1835.669104
# min      0.000000  1.703101e+10   11457.000000      1.000000       416.000000
# 25%    223.500000  1.703119e+10   44920.000000     92.500000      2279.000000
# 50%    453.000000  1.703144e+10   67044.000000    317.500000      3489.000000
# 75%    682.500000  1.703181e+10  107213.000000   1058.750000      4865.500000
# max    922.000000  1.703184e+10  250000.000000  44804.000000     19889.000000
#
#        Population_Density   Employment_Density  Percent_Zero_Car_Ownership  \
# count          895.000000           895.000000                  895.000000
# mean            31.126855            11.433281                    0.207805
# ...

# %%
raw_data.to_csv("july_cleaned.csv")
